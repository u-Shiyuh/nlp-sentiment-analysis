# %% [markdown]
# # Midterm Group 7
# King Matthew Ochoa <br>
# Edmalyn Pacanor<br>
# Jerimiah Riesgo<br>
# Use the twitter dataset about covid vaccine to classify the sentiment about covid vaccination. Interpret your result.

# %%
import pandas as pd
import numpy as np
import string

# %%
df = pd.read_csv('vaccination_all_tweets-1.csv')
df
# Out:
#                         id             user_name  \
# 0      1340539111971516416            Rachel Roh
# 1      1338158543359250433           Albert Fong
# 2      1337858199140118533              eli🇱🇹🇪🇺👌
# 3      1337855739918835717         Charles Adler
# 4      1337854064604966912  Citizen News Channel
# ...                    ...                   ...
# 88973  1396835959271043074             The Hindu
# 88974  1396834454878961664     Workout Solutions
# 88975  1396834341313908741          Truth Behind
# 88976  1396834288608464899     Workout Solutions
# 88977  1396833781739261953      The English Post
#
#                         user_location  \
# 0           La Crescenta-Montrose, CA
# 1                   San Francisco, CA
# 2                            Your Bed
# 3              Vancouver, BC - Canada
# 4                                 NaN
# ...                               ...
# 88973                  Chennai, India
# 88974  Toronto, Canada  and Worldwide
# 88975                          Earth
# 88976  Toronto, Canada  and Worldwide
# 88977                           India
#
#                                         user_description         user_created  \
# 0      Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1      Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 2                                         heil, hydra 🖐☺  2020-06-25 23:30:28
# 3      Hosting "CharlesAdlerTonight" Global News Radi...  2008-09-10 11:28:53
# 4      Citizen News Channel bringing you an alternati...  2020-04-23 17:58:42
# ...                                                  ...                  ...
# 88973         News feeds from India's National Newspaper  2009-02-13 06:04:24
# 88974  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
# 88975  Knows everything. Serial Commenter . Follow if...  2020-09-11 11:55:02
# 88976  George Tsanis – Workout Solutions Health and F...  2010-09-20 17:01:08
# 88977  The English Post brings you news from around t...  2016-09-19 17:48:00
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 0                 405          1692             3247          False
# 1                 834           666              178          False
# 2                  10            88              155          False
# 3               49165          3933            21853           True
# 4                 152           580             1473          False
# ...               ...           ...              ...            ...
# 88973         6950525           211              154           True
# 88974            1227           336             4305          False
# 88975              14            39              375          False
# 88976            1227           336             4305          False
# 88977            5049           295                1          False
#
#                       date                                               text  \
# 0      2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# 1      2020-12-13 16:27:13  While the world has been on the wrong side of ...
# 2      2020-12-12 20:33:45  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3      2020-12-12 20:23:59  Facts are immutable, Senator, even when you're...
# 4      2020-12-12 20:17:19  Explain to me again why we need a vaccine @Bor...
# ...                    ...                                                ...
# 88973  2021-05-24 14:30:19  India’s Panacea Biotec has started producing #...
# 88974  2021-05-24 14:24:20  @globeandmail Canada stop politicizing #vaccin...
# 88975  2021-05-24 14:23:53  Look @ArvindKejriwal \n\n#uselessCM #resignnow...
# 88976  2021-05-24 14:23:40  @globalnewsto Canada stop politicizing #vaccin...
# 88977  2021-05-24 14:21:40  RDIF, Panacea Biotec to start Sputnik V produc...
#
#                                                 hashtags               source  \
# 0                                     ['PfizerBioNTech']  Twitter for Android
# 1                                                    NaN      Twitter Web App
# 2      ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                    NaN      Twitter Web App
# 4         ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
# ...                                                  ...                  ...
# 88973                            ['SputnikV', 'COVID19']           SocialFlow
# 88974                            ['vaccine', 'lockdown']      Twitter Web App
# 88975  ['uselessCM', 'resignnow', 'KejriwalFailsDelhi...   Twitter for iPhone
# 88976                            ['vaccine', 'lockdown']      Twitter Web App
# 88977                                       ['SputnikV']      Twitter Web App
#
#        retweets  favorites  is_retweet
# 0             0          0       False
# 1             1          1       False
# 2             0          0       False
# 3           446       2129       False
# 4             0          0       False
# ...         ...        ...         ...
# 88973        14        110       False
# 88974         0          0       False
# 88975         0          0       False
# 88976         0          0       False
# 88977         0          0       False
#
# [88978 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['id', 'user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'retweets', 'favorites',
#        'is_retweet'],
#       dtype='object')

# %%
#df1 = df.drop(['user_location','user_verified'],axis = 1)

# %%
#get only the tweets
df_text = df[['text']]

# %%
#remove the punctation
import warnings
warnings.filterwarnings(action='ignore')
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree
#storing the puntuation free text
df_text['text']= df_text['text'].apply(lambda x:remove_punctuation(x))

# %%
#make all lowercase
df_text['text'] = df_text['text'].apply(lambda x: x.lower())

# %%
#defining function for tokenization
import re
def tokenization(text):
    tokens = re.split('W+',text)
    return tokens
#applying function to the column
df_text['text'] = df_text['text'].apply(lambda x: tokenization(x))
df_text
# Out:
#                                                     text
# 0      [same folks said daikon paste could treat a cy...
# 1      [while the world has been on the wrong side of...
# 2      [coronavirus sputnikv astrazeneca pfizerbionte...
# 3      [facts are immutable senator even when youre n...
# 4      [explain to me again why we need a vaccine bor...
# ...                                                  ...
# 88973  [india’s panacea biotec has started producing ...
# 88974  [globeandmail canada stop politicizing vaccine...
# 88975  [look arvindkejriwal \n\nuselesscm resignnow k...
# 88976  [globalnewsto canada stop politicizing vaccine...
# 88977  [rdif panacea biotec to start sputnik v produc...
#
# [88978 rows x 1 columns]

# %%
#Removing stopwords
import nltk
#Stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')

def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

#applying the function
df_text['text'] = df_text['text'].apply(lambda x:remove_stopwords(x))

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
lemma = WordNetLemmatizer()
stop_words = stopwords.words('english')

def text_prep(x):
     corp = str(x).lower() 
     corp = re.sub('[^a-zA-Z]+',' ', corp).strip() 
     tokens = word_tokenize(corp)
     words = [t for t in tokens if t not in stop_words]
     lemmatize = [lemma.lemmatize(w) for w in words]
    
     return lemmatize

df_text['text'] = [text_prep(i) for i in df_text['text']]

# %%
# Downloded from => https://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html
file = open('negative-words.txt', 'r')
neg_words = file.read().split()
file = open('positive-words.txt', 'r')
pos_words = file.read().split()

# %%
df_text['positive']= df_text['text'].map(lambda x: len([i for i in x if i in pos_words]))

# %%
df_text['negative'] =df_text['text'].map(lambda x: len([i for i in x if i in neg_words]))

# %%
df_text['total_len'] = df_text['text'].map(lambda x: len(x))

# %%
df_text['sentiment'] = round((df_text['positive'] - df_text['negative']) / df_text['total_len'], 2)

# %%
df_text.sort_values(by ='positive', ascending = False)
# Out:
#                                                     text  pos  negative  \
# 58783  [safe, effective, safe, effective, safe, effec...    0         0
# 19776  [yay, got, jab, yay, great, day, gop, brillian...    0         0
# 57655  [took, jab, gave, silent, salute, genius, amp,...    0         0
# 51349  [easy, brave, sometimes, courageous, thing, st...    0         0
# 43344  [vaccinedone, covaxin, kmc, jyoti, mangaluru, ...    0         0
# ...                                                  ...  ...       ...
# 37115  [astrazeneca, scandal, ntwo, clot, found, euro...    0         1
# 37116  [second, vaccine, dose, done, getvaccinated, o...    0         0
# 37117  [tried, nsee, brought, vaccine, called, shield...    0         0
# 37118  [one, go, eleven, week, time, oxfordastrazenec...    0         0
# 88977  [rdif, panacea, biotec, start, sputnik, v, pro...    0         0
#
#        total_len  positive  sentiment
# 58783         14        11       0.79
# 19776         15         7       0.47
# 57655         13         6       0.46
# 51349         12         6       0.50
# 43344         14         6       0.43
# ...          ...       ...        ...
# 37115         13         0      -0.08
# 37116          6         0       0.00
# 37117          9         0       0.00
# 37118          9         0       0.00
# 88977         13         0       0.00
#
# [88978 rows x 6 columns]

# %%
from nltk.stem import WordNetLemmatizer
#defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()


def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text

df_text['text'] = df_text['text'].apply(lambda x:lemmatizer(x))
# Out:
# C:\Users\Shiyuh\AppData\Local\Temp/ipykernel_17600/3132535510.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['text'] = df_text['text'].apply(lambda x:lemmatizer(x))

# %%
df_text
# Out:
#                                                     text
# 0      [same folks said daikon paste could treat a cy...
# 1      [while the world has been on the wrong side of...
# 2      [coronavirus sputnikv astrazeneca pfizerbionte...
# 3      [facts are immutable senator even when youre n...
# 4      [explain to me again why we need a vaccine bor...
# ...                                                  ...
# 88973  [india’s panacea biotec has started producing ...
# 88974  [globeandmail canada stop politicizing vaccine...
# 88975  [look arvindkejriwal \n\nuselesscm resignnow k...
# 88976  [globalnewsto canada stop politicizing vaccine...
# 88977  [rdif panacea biotec to start sputnik v produc...
#
# [88978 rows x 1 columns]

# %% [markdown]
# # splitting dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.05, random_state =0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17600/3640189991.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.05, random_state =0)
#
# NameError: name 'X' is not defined
